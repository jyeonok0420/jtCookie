# %% [markdown]
# <a href="https://colab.research.google.com/github/jyeonok0420/jtCookie/blob/main/Drawing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = np.zeros((512,512,3), np.uint8)
#cv2.line(img,(0,0),(img.shape[1],img.shape[0]),(0,255,0),3)
cv2.circle(img,(100,100),50,(0,255,0),10)
cv2.rectangle(img,(200,200),(400,500),(0,0,255),5)
cv2.line(img,(160,160),(355,29),(255,0, 0),3)
cv2.putText(img,"opencv",(280,150),cv2.FONT_HERSHEY_COMPLEX,2,(255,255,255),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
